# %%
import pandas as pd

df = pd.DataFrame([['Ali', 20, 'Lahore'], ['Sara', 22, 'Karachi'], ['Ahmed', 21, 'Islamabad']], columns=['Name', 'Age', 'City'])

df
# Out:
#     Name  Age       City
# 0    Ali   20     Lahore
# 1   Sara   22    Karachi
# 2  Ahmed   21  Islamabad

# %%
print(df.head(2))
print(df.columns)
print(df.shape)
# Out:
#    Name  Age     City
# 0   Ali   20   Lahore
# 1  Sara   22  Karachi
# Index(['Name', 'Age', 'City'], dtype='str')
# (3, 3)

# %%
print(df['Name'])
print(df[['Name', 'City']])
# Out:
# 0      Ali
# 1     Sara
# 2    Ahmed
# Name: Name, dtype: str
#     Name  Age
# 0    Ali   20
# 1   Sara   22
# 2  Ahmed   21

# %%
df[(df['Age'] > 20)]
# Out:
#     Name  Age       City
# 1   Sara   22    Karachi
# 2  Ahmed   21  Islamabad

# %%
df['Grade'] = ['A','B', 'A']
df

# better practice 
# df = df.assign(Grade=['A','B','A'])
# Out:
#     Name  Age       City Grade
# 0    Ali   20     Lahore     A
# 1   Sara   22    Karachi     B
# 2  Ahmed   21  Islamabad     A
